# %% [markdown]
# 2. EXPLORACION  🦾🧠🧠
#
# Usamos la librerias de panadas y matplotlib (graficos)

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Lo hacemoos disponible el archivo anterior

# %%
compras_df=pd.read_csv('/content/drive/MyDrive/PROYETO CLASE/clean_compras.csv')
compras_df.head(5)
# Out:
#    NUM BEN                                    BENEFICIARIO           RFC  \
# 0   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# ...

# %% [markdown]
# VISION GENERAL DEL DATA SET
#
# 1. Empezamos trayendo todo el tipo de columnas que tenemos
# 2. Verificamos el tipo de datos (puede haber cambiado con el guardado)
# 3.Verificamos las columnas numericas
# 4. Indicamos con cuales columnas vamos a trabajar

# %%
compras_df.columns
# Out:
# Index(['NUM BEN', 'BENEFICIARIO', 'RFC', 'FACTURA', 'CONTRATO', 'CONCEPTO',
#        'TIPO', '# OP', 'FECHA', 'IMPORTE', 'SHEET'],
#       dtype='object')

# %%
compras_df.dtypes
# Out:
# NUM BEN           int64
# BENEFICIARIO     object
# RFC              object
# FACTURA          object
# CONTRATO         object
# CONCEPTO         object
# TIPO             object
# # OP            float64
# FECHA            object
# IMPORTE         float64
# SHEET            object
# dtype: object

# %%
compras_df.describe()
# Out:
#              NUM BEN          # OP       IMPORTE
# count    1540.000000  1.540000e+03  1.540000e+03
# mean   203914.777273  1.920050e+08  6.263179e+05
# std     92435.932025  1.411189e+08  4.666912e+06
# min    110152.000000  1.019042e+06  8.600000e-01
# 25%    116223.000000  1.019144e+06  2.987000e+03
# 50%    203013.000000  2.980000e+08  1.235584e+04
# 75%    311250.000000  3.000001e+08  1.130583e+05
# max    370012.000000  6.040001e+08  1.267303e+08

# %%
compras_df=compras_df[['BENEFICIARIO', 'RFC', 'FACTURA', 'CONTRATO', 'CONCEPTO','TIPO', '# OP', 'FECHA', 'IMPORTE', 'SHEET']]

# %% [markdown]
# ANALISIS UNIDIMENSIONAL DE LAS VARIABLES
#
# * Revisamos cuantos registros hay por tablas , gracias a la columna extra que le agregamos para identificar que dato pertenecia a que tabla
# * Contamos la cantidad de caracteres
# *identificamos cantidad de veces de cada beneficiario
# *Graficamos en modo de histograma el importe ($)

# %%
compras_df['SHEET'].value_counts()
# Out:
# CONTRATISTAS Y FDO FED    724
# GASTOS VARIOS             690
# COMUNICACION               71
# SERV. PERS.                46
# SERV PPROF                  9
# Name: SHEET, dtype: int64

# %%
len (compras_df['CONCEPTO'].unique())
# Out:
# 1396

# %%
compras_df['BENEFICIARIO'].value_counts()
# Out:
# CAMARA MEXICANA DE LA INDUSTRIA DE LA CONSTRUCCION    266
# AUTOKAM REGIOMONTANA,S.A.DE C.V.                      101
# CAR ONE MONTERREY, S.A. DE C.V.                        78
# PEREZ RIOS RAMIRO                                      58
# S.I.M.E.P.R.O.D.E.                                     50
#                                                      ...
# LOMAS LOZANO CLAUDIA PATRICIA                           1
# MADERA HOLTEN MARIA TERESA                              1
# MORENO MARTINEZ SONIA                                   1
# OLDER GARCIA CARLOS ALBERTO                             1
# TOVAR CEDILLO JAVIER ALFONSO                            1
# Name: BENEFICIARIO, Length: 301, dtype: int64

# %% [markdown]
# PUEDO TRAER LOS DIEZ PRIEMROS

# %%
compras_df['BENEFICIARIO'].value_counts() [0:10]
# Out:
# CAMARA MEXICANA DE LA INDUSTRIA DE LA CONSTRUCCION    266
# AUTOKAM REGIOMONTANA,S.A.DE C.V.                      101
# CAR ONE MONTERREY, S.A. DE C.V.                        78
# PEREZ RIOS RAMIRO                                      58
# S.I.M.E.P.R.O.D.E.                                     50
# INTERASFALTOS, S.A. DE C.V.                            45
# GRUPO COYOTE MONTERREY, S.A. DE C.V.                   43
# SERVICIO TECNICO CHURUBUSCO, S.A. DE C.V.              30
# CFE SUMINISTRADOR DE SERVICIOS BASICOS                 29
# CORDERO MACIAS SILVESTRE GUADALUPE                     27
# Name: BENEFICIARIO, dtype: int64

# %%
compras_df['IMPORTE'].hist()

# %%
compras_df[compras_df['IMPORTE']< compras_df['IMPORTE'].quantile(0.95)]['IMPORTE'].hist()

# %%
compras_df[compras_df['IMPORTE']< compras_df['IMPORTE'].quantile(0.95)]['IMPORTE'].hist(bins=50)

# %%
compras_df[compras_df['IMPORTE']< compras_df['IMPORTE'].quantile(0.95)].head(5)
# Out:
#                                      BENEFICIARIO           RFC  \
# 0  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# 2  REEMPLAZO DE DOS RINES  (17). PATRIMONIO 80383...   TR    1019110.0
# ...

# %% [markdown]
# ANALISIS MULTIDIMENSIONAL DE VARIABLES
#
# 1. SUMAMOS EL TOTAL DE IMPORTES DE CADA BENEFICIARIO

# %%
sum_importe_benefeciario=compras_df.groupby('BENEFICIARIO').sum()['IMPORTE']
sum_importe_benefeciario
# Out:
# BENEFICIARIO
# 235 PROYECTOS, S.A. DE C.V.                   1649292.36
# ABC Y CONSTRUCCIONES, SA. DE CV.              1311087.90
# ACEROS Y OVEROLLINGS DE MEXICO, SA. DE CV.       5914.30
# ADQUISICIONES INTELIGENTES, S.A. DE C.V.      2132196.00
# ALIANZA AUTOMOTRIZ RIVERO, SA. DE CV.          450859.52
#                                                  ...
# VILLARREAL CARDENAS JUAN IGNACIO                 3733.13
# VILLARREAL CARDENAS NANCY ESTHER                81461.14
# VILLARREAL DE LEON BERTHA                       11004.05
# VIVERO EL ESCORIAL, S.A. DE C.V.              2511255.46
# ZAPATA CHAVIRA HOMERO ARTURO                    28350.00
# Name: IMPORTE, Length: 301, dtype: float64

# %%
sum_importe_benefeciario.reset_index().sort_values(by='IMPORTE', ascending=False).iloc [0:10].plot(kind='bar',x='BENEFICIARIO', y='IMPORTE')
# Out:
# <AxesSubplot:xlabel='BENEFICIARIO'>

# %%
mean_import_sheet=compras_df.groupby('SHEET').mean()['IMPORTE']
mean_import_sheet.reset_index().sort_values(by='IMPORTE', ascending=False).iloc [0:10].plot(kind='bar', x='SHEET',y='IMPORTE')
# Out:
# <AxesSubplot:xlabel='SHEET'>

# %%
sum_import_sheet=compras_df.groupby('FECHA').sum()['IMPORTE']
sum_import_sheet.reset_index().sort_values(by='IMPORTE', ascending=False).iloc [0:10].plot(kind='bar', x='FECHA',y='IMPORTE')
# Out:
# <AxesSubplot:xlabel='FECHA'>

# %%
compras_gastos_df= compras_df[compras_df['SHEET']=='GASTOS VARIOS']
compras_gastos_df ['IMPORTE'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
compras_df[compras_df['BENEFICIARIO']=='LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.']['SHEET'].value_counts()
# Out:
# GASTOS VARIOS    13
# Name: SHEET, dtype: int64

# %%
compras_sheet_beneficiario=compras_df.groupby(['BENEFICIARIO', 'SHEET']).sum()['IMPORTE'].sort_values().unstack('SHEET')

# %%
top_beneficiarios = compras_df.groupby('BENEFICIARIO')['IMPORTE'].sum().sort_values(ascending=False).index[0:10]
top_beneficiarios
# Out:
# Index(['MUNICIPIO DE LA CIUDAD DE MONTERREY',
#        'INTEGRACION DE SISTEMAS DE AVANZADA TECNOLOGIA, S.A. DE C.V.',
#        'VALUE ARRENDADORA,S.A.DE C.V. SOFOM ER VALUE GPO.FIN.',
#        'CAR ONE MONTERREY, S.A. DE C.V.',
#        'BANCO BANCREA,S.A. ,FIDEICOMISO NUMERO BP417',
#        'SI VALE MEXICO, S.A. DE C.V.', 'INTERASFALTOS, S.A. DE C.V.',
#        'RED RECOLECTOR, S.A. DE C.V.', 'SERVICIOS BROXEL, S.A.P.I. DE C.V.',
#        'PROYECTOS Y DESARROLLOS SALVE, SA. DE CV.'],
#       dtype='object', name='BENEFICIARIO')

# %%
compras_sheet_beneficiario.loc[top_beneficiarios].plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='BENEFICIARIO'>

# %% [markdown]
# ## ANALISIS DE TEXTO

# %%
import nltk 
nltk.download('book')
from nltk.book import *
from nltk.corpus import stopwords
print(stopwords.words('spanish'))
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
textos_compras = ''
for row in compras_df['CONCEPTO']: 
    textos_compras = textos_compras + ' ' + row

# %%
stopwords_list = stopwords.words('spanish') + ['2020', 'cont', 'millar', 'dpp', 'est', 'op', 'ret', 'mty', 'icom']

# %%
textos_compras = ' '.join([x for x in textos_compras.strip().lower().split(' ') if x not in stopwords_list and len(x)>4])

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc = WordCloud(background_color= 'white')
wc.generate(textos_compras)

plt.axis("off")
plt.imshow(wc, interpolation='bilinear')
plt.show()
